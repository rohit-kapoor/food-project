# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/rohit-kapoor/food-project/blob/master/got_the_file_finally.ipynb)

# %%
import urlparse2
import html2text
from bs4 import BeautifulSoup
import urllib
import urllib.request
import re
import os
import csv
import re
import requests
outfile = open('Indian Food Nutrition.csv','wb')
header = 'Food, Serving Size, Calories, Fat, Carbohydrates, Protein'+'\n'
outfile.write(bytes(header,encoding="ascii", errors='ignore'))

for i in range(1,100):
    #print(i)
    url='http://www.myfitnesspal.com/nutrition-facts-calories/indian-food/'+ str(i)
    data = urllib.request.urlopen(url)
    #data.read()
    soup = BeautifulSoup(data,'html.parser')
   # print(soup)   
    for j in soup.findAll('div',{'class':'food_info'}):
        print(j.text)
        data2 = j.text.split('\n')
        list = []
        for i in data2:
            i = str(i)
            i = i.replace('\t','')
            if i != '':
                list.append(i)
        print(list)
        tmp = list.pop(0)
        list[0] = str(tmp + list[0]).replace(',','')
        list[1] = str(list[1]).replace(',','')[13:]
        list[2] = str(list[2]).replace(',','')[11:]
        list[3] = str(list[3]).replace(',','')[6:]
        list[4] = str(list[4]).replace(',','')[8:]
        list[5] = str(list[5]).replace(',','')[10:]

        print(list)


        rowdata = ''
        for i in list:
            rowdata = rowdata + str(i) + ' , '
        rowdata = rowdata + '\n'
        print(rowdata)
        outfile.write(bytes(rowdata,encoding="ascii", errors='ignore'))
# Out:
# Tosai
# 				(Indian Food)
#
#
# Serving Size: 	1 tosai,
# 					Calories:  80,
# 					Fat:  2g,
# 					Carbs:  17g,
# 					Protein:  2.3g
#
#
# ['Tosai ', '(Indian Food)', 'Serving Size: 1 tosai,', 'Calories:  80,', 'Fat:  2g,', 'Carbs:  17g,', 'Protein:  2.3g']
# ['Tosai (Indian Food)', ' 1 tosai', '80', '2g', '17g', '2.3g']
# Tosai (Indian Food) ,  1 tosai , 80 , 2g , 17g , 2.3g ,
#
#
#
# Shev Dahi Batata Puri
# 				(Indian Food-)
#
#
# Serving Size: 	4 balls,
# 					Calories:  379,
# 					Fat:  9.5g,
# 					Carbs:  64g,
# 					Protein:  12.2g
#
#
# ['Shev Dahi Batata Puri ', '(Indian Food-)', 'Serving Size: 4 balls,', 'Calories:  379,', 'Fat:  9.5g,', 'Carbs:  64g,', 'Protein:  12.2g']
# ['Shev Dahi Batata Puri (Indian Food-)', ' 4 balls', '379', '9.5g', '64g', '12.2g']
# Shev Dahi Batata Puri (Indian Food-) ,  4 balls , 379 , 9.5g , 64g , 12.2g ,
#
#
#
# Curry
# 				(Indian Food)
#
#
# Serving Size: 	100 G,
# 					Calories:  100,
# 					Fat:  5.1g,
# 					Carbs:  15g,
# 					Protein:  2.9g
#
#
# ['Curry ', '(Indian Food)', 'Serving Size: 100 G,', 'Calories:  100,', 'Fat:  5.1g,', 'Carbs:  15g,', 'Protein:  2.9g']
# ['Curry (Indian Food)', ' 100 G', '100', '5.1g', '15g', '2.9g']
# Curry (Indian Food) ,  100 G , 100 , 5.1g , 15g , 2.9g ,
#
#
#
# Shimla Mirch Aloo
# 				(Indian Food)
#
#
# Serving Size: 	100 G,
# 					Calories:  93,
# 					Fat:  3.4g,
# 					Carbs:  12.8g,
# 					Protein:  1.5g
#
#
# ['Shimla Mirch Aloo ', '(Indian Food)', 'Serving Size: 100 G,', 'Calories:  93,', 'Fat:  3.4g,', 'Carbs:  12.8g,', 'Protein:  1.5g']
# ['Shimla Mirch Aloo (Indian Food)', ' 100 G', '93', '3.4g', '12.8g', '1.5g']
# Shimla Mirch Aloo (Indian Food) ,  100 G , 93 , 3.4g , 12.8g , 1.5g ,
#
#
#
# Nasi Bryani (Rice Only) Singapore
# 				(Indian Food)
#
#
# Serving Size: 	1 Plate,
# 					Calories:  458,
# 					Fat:  14g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Nasi Bryani (Rice Only) Singapore ', '(Indian Food)', 'Serving Size: 1 Plate,', 'Calories:  458,', 'Fat:  14g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Nasi Bryani (Rice Only) Singapore (Indian Food)', ' 1 Plate', '458', '14g', '0g', '0g']
# Nasi Bryani (Rice Only) Singapore (Indian Food) ,  1 Plate , 458 , 14g , 0g , 0g ,
#
#
#
# Vadi
# 				(Indian Food)
#
#
# Serving Size: 	1 piece,
# 					Calories:  100,
# 					Fat:  29.6g,
# 					Carbs:  18.5g,
# 					Protein:  4.8g
#
#
# ['Vadi ', '(Indian Food)', 'Serving Size: 1 piece,', 'Calories:  100,', 'Fat:  29.6g,', 'Carbs:  18.5g,', 'Protein:  4.8g']
# ['Vadi (Indian Food)', ' 1 piece', '100', '29.6g', '18.5g', '4.8g']
# Vadi (Indian Food) ,  1 piece , 100 , 29.6g , 18.5g , 4.8g ,
#
#
#
# Brown Rice With Lentils and Vegetables
# 				(Indian Food)
#
#
# Serving Size: 	1 cup,
# 					Calories:  500,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Brown Rice With Lentils and Vegetables ', '(Indian Food)', 'Serving Size: 1 cup,', 'Calories:  500,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Brown Rice With Lentils and Vegetables (Indian Food)', ' 1 cup', '500', '0g', '0g', '0g']
# Brown Rice With Lentils and Vegetables (Indian Food) ,  1 cup , 500 , 0g , 0g , 0g ,
#
#
#
# Chicken Masala W/ Naan Wrap
# 				(Indian Food)
#
#
# Serving Size: 	1 wrap,
# 					Calories:  195,
# 					Fat:  8.1g,
# 					Carbs:  30.5g,
# 					Protein:  20.4g
#
#
# ['Chicken Masala W/ Naan Wrap ', '(Indian Food)', 'Serving Size: 1 wrap,', 'Calories:  195,', 'Fat:  8.1g,', 'Carbs:  30.5g,', 'Protein:  20.4g']
# ['Chicken Masala W/ Naan Wrap (Indian Food)', ' 1 wrap', '195', '8.1g', '30.5g', '20.4g']
# Chicken Masala W/ Naan Wrap (Indian Food) ,  1 wrap , 195 , 8.1g , 30.5g , 20.4g ,
#
#
#
# Aloo Baigan Cooked Vegitable
# 				(Indian Food)
#
#
# Serving Size: 	1 cup cooked,
# 					Calories:  103,
# 					Fat:  4.7g,
# 					Carbs:  12.3g,
# 					Protein:  1.3g
#
#
# ['Aloo Baigan Cooked Vegitable ', '(Indian Food)', 'Serving Size: 1 cup cooked,', 'Calories:  103,', 'Fat:  4.7g,', 'Carbs:  12.3g,', 'Protein:  1.3g']
# ['Aloo Baigan Cooked Vegitable (Indian Food)', ' 1 cup cooked', '103', '4.7g', '12.3g', '1.3g']
# Aloo Baigan Cooked Vegitable (Indian Food) ,  1 cup cooked , 103 , 4.7g , 12.3g , 1.3g ,
#
#
#
# Dosai
# 				(Indian Food)
#
#
# Serving Size: 	1 medium,
# 					Calories:  80,
# 					Fat:  2.5g,
# 					Carbs:  30g,
# 					Protein:  12.8g
#
#
# ['Dosai ', '(Indian Food)', 'Serving Size: 1 medium,', 'Calories:  80,', 'Fat:  2.5g,', 'Carbs:  30g,', 'Protein:  12.8g']
# ['Dosai (Indian Food)', ' 1 medium', '80', '2.5g', '30g', '12.8g']
# Dosai (Indian Food) ,  1 medium , 80 , 2.5g , 30g , 12.8g ,
#
#
#
# Vegetable Jhalfrezi
# 				(Indian Food)
#
#
# Serving Size: 	1 c prepared,
# 					Calories:  200,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Vegetable Jhalfrezi ', '(Indian Food)', 'Serving Size: 1 c prepared,', 'Calories:  200,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Vegetable Jhalfrezi (Indian Food)', ' 1 c prepared', '200', '0g', '0g', '0g']
# Vegetable Jhalfrezi (Indian Food) ,  1 c prepared , 200 , 0g , 0g , 0g ,
#
#
#
# Lapsi (Sweet Bulgur)
# 				(Indian Food)
#
#
# Serving Size: 	1/2 cup,
# 					Calories:  380,
# 					Fat:  15g,
# 					Carbs:  53g,
# 					Protein:  6g
#
#
# ['Lapsi (Sweet Bulgur) ', '(Indian Food)', 'Serving Size: 1/2 cup,', 'Calories:  380,', 'Fat:  15g,', 'Carbs:  53g,', 'Protein:  6g']
# ['Lapsi (Sweet Bulgur) (Indian Food)', ' 1/2 cup', '380', '15g', '53g', '6g']
# Lapsi (Sweet Bulgur) (Indian Food) ,  1/2 cup , 380 , 15g , 53g , 6g ,
#
#
#
# Aloo Gobi Masala Internet
# 				(Indian Food)
#
#
# Serving Size: 	1 cup,
# 					Calories:  203.6,
# 					Fat:  5.5g,
# 					Carbs:  35.1g,
# 					Protein:  6.6g
#
#
# ['Aloo Gobi Masala Internet  ', '(Indian Food)', 'Serving Size: 1 cup,', 'Calories:  203.6,', 'Fat:  5.5g,', 'Carbs:  35.1g,', 'Protein:  6.6g']
# ['Aloo Gobi Masala Internet  (Indian Food)', ' 1 cup', '203.6', '5.5g', '35.1g', '6.6g']
# Aloo Gobi Masala Internet  (Indian Food) ,  1 cup , 203.6 , 5.5g , 35.1g , 6.6g ,
#
#
#
# Papadom
# 				(Indian Food)
#
#
# Serving Size: 	3 pcs/10g,
# 					Calories:  20,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Papadom ', '(Indian Food)', 'Serving Size: 3 pcs/10g,', 'Calories:  20,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Papadom (Indian Food)', ' 3 pcs/10g', '20', '0g', '0g', '0g']
# Papadom (Indian Food) ,  3 pcs/10g , 20 , 0g , 0g , 0g ,
#
#
#
# Sardine Paratel
# 				(Indian Food)
#
#
# Serving Size: 	1 cup,
# 					Calories:  156,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Sardine Paratel ', '(Indian Food)', 'Serving Size: 1 cup,', 'Calories:  156,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Sardine Paratel (Indian Food)', ' 1 cup', '156', '0g', '0g', '0g']
# Sardine Paratel (Indian Food) ,  1 cup , 156 , 0g , 0g , 0g ,
#
#
#
# Capati
# 				(Indian Food)
#
#
# Serving Size: 	1 pcs/38g,
# 					Calories:  106.5,
# 					Fat:  2.5g,
# 					Carbs:  20g,
# 					Protein:  3g
#
#
# ['Capati ', '(Indian Food)', 'Serving Size: 1 pcs/38g,', 'Calories:  106.5,', 'Fat:  2.5g,', 'Carbs:  20g,', 'Protein:  3g']
# ['Capati (Indian Food)', ' 1 pcs/38g', '106.5', '2.5g', '20g', '3g']
# Capati (Indian Food) ,  1 pcs/38g , 106.5 , 2.5g , 20g , 3g ,
#
#
#
# Tomato Chicken
# 				(Indian Food)
#
#
# Serving Size: 	1/2 cup,
# 					Calories:  134,
# 					Fat:  5.4g,
# 					Carbs:  6.9g,
# 					Protein:  14.7g
#
#
# ['Tomato Chicken ', '(Indian Food)', 'Serving Size: 1/2 cup,', 'Calories:  134,', 'Fat:  5.4g,', 'Carbs:  6.9g,', 'Protein:  14.7g']
# ['Tomato Chicken (Indian Food)', ' 1/2 cup', '134', '5.4g', '6.9g', '14.7g']
# Tomato Chicken (Indian Food) ,  1/2 cup , 134 , 5.4g , 6.9g , 14.7g ,
#
#
#
# Abc
# 				(Indian Food)
#
#
# Serving Size: 	1 cup/50g,
# 					Calories:  90,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Abc ', '(Indian Food)', 'Serving Size: 1 cup/50g,', 'Calories:  90,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Abc (Indian Food)', ' 1 cup/50g', '90', '0g', '0g', '0g']
# Abc (Indian Food) ,  1 cup/50g , 90 , 0g , 0g , 0g ,
#
#
#
# Banana Leaf Rice
# 				(Indian Food)
#
#
# Serving Size: 	1 set,
# 					Calories:  265,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Banana Leaf Rice ', '(Indian Food)', 'Serving Size: 1 set,', 'Calories:  265,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Banana Leaf Rice (Indian Food)', ' 1 set', '265', '0g', '0g', '0g']
# Banana Leaf Rice (Indian Food) ,  1 set , 265 , 0g , 0g , 0g ,
#
#
#
# Medu Vada, (Indian Doughnut Shaped Snack Made From Black Lentils)
# 				(Indian Food)
#
#
# Serving Size: 	2 pieces,
# 					Calories:  334,
# 					Fat:  11g,
# 					Carbs:  43g,
# 					Protein:  14g
#
#
# ['Medu Vada, (Indian Doughnut Shaped Snack Made From Black Lentils) ', '(Indian Food)', 'Serving Size: 2 pieces,', 'Calories:  334,', 'Fat:  11g,', 'Carbs:  43g,', 'Protein:  14g']
# ['Medu Vada (Indian Doughnut Shaped Snack Made From Black Lentils) (Indian Food)', ' 2 pieces', '334', '11g', '43g', '14g']
# Medu Vada (Indian Doughnut Shaped Snack Made From Black Lentils) (Indian Food) ,  2 pieces , 334 , 11g , 43g , 14g ,
#
#
#
# Lamb Vindaloo (No Rice Fo Real)
# 				(Indian Food)
#
#
# Serving Size: 	4 oz,
# 					Calories:  360,
# 					Fat:  15g,
# 					Carbs:  8g,
# 					Protein:  25g
#
#
# ['Lamb Vindaloo (No Rice Fo Real) ', '(Indian Food)', 'Serving Size: 4 oz,', 'Calories:  360,', 'Fat:  15g,', 'Carbs:  8g,', 'Protein:  25g']
# ['Lamb Vindaloo (No Rice Fo Real) (Indian Food)', ' 4 oz', '360', '15g', '8g', '25g']
# Lamb Vindaloo (No Rice Fo Real) (Indian Food) ,  4 oz , 360 , 15g , 8g , 25g ,
#
#
#
# Mulligatawny Soup
# 				(Indian Food)
#
#
# Serving Size: 	1 cup,
# 					Calories:  100,
# 					Fat:  2g,
# 					Carbs:  12g,
# 					Protein:  0g
#
#
# ['Mulligatawny Soup ', '(Indian Food)', 'Serving Size: 1 cup,', 'Calories:  100,', 'Fat:  2g,', 'Carbs:  12g,', 'Protein:  0g']
# ['Mulligatawny Soup (Indian Food)', ' 1 cup', '100', '2g', '12g', '0g']
# Mulligatawny Soup (Indian Food) ,  1 cup , 100 , 2g , 12g , 0g ,
#
#
#
# Vegetable Balti
# 				(Indian Food)
#
#
# Serving Size: 	1 portion,
# 					Calories:  290,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Vegetable Balti ', '(Indian Food)', 'Serving Size: 1 portion,', 'Calories:  290,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Vegetable Balti (Indian Food)', ' 1 portion', '290', '0g', '0g', '0g']
# Vegetable Balti (Indian Food) ,  1 portion , 290 , 0g , 0g , 0g ,
#
#
#
# Dhaba Murg (Chicken, Onion, Tomato, Coriander, Chilies)
# 				(Indian Food)
#
#
# Serving Size: 	1 portion,
# 					Calories:  210,
# 					Fat:  4g,
# 					Carbs:  6g,
# 					Protein:  35g
#
#
# ['Dhaba Murg (Chicken, Onion, Tomato, Coriander, Chilies) ', '(Indian Food)', 'Serving Size: 1 portion,', 'Calories:  210,', 'Fat:  4g,', 'Carbs:  6g,', 'Protein:  35g']
# ['Dhaba Murg (Chicken Onion Tomato Coriander Chilies) (Indian Food)', ' 1 portion', '210', '4g', '6g', '35g']
# Dhaba Murg (Chicken Onion Tomato Coriander Chilies) (Indian Food) ,  1 portion , 210 , 4g , 6g , 35g ,
#
#
#
# Aloo Pat Gobi
# 				(Indian Food)
#
#
# Serving Size: 	100 g,
# 					Calories:  75,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Aloo Pat Gobi ', '(Indian Food)', 'Serving Size: 100 g,', 'Calories:  75,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Aloo Pat Gobi (Indian Food)', ' 100 g', '75', '0g', '0g', '0g']
# Aloo Pat Gobi (Indian Food) ,  100 g , 75 , 0g , 0g , 0g ,
#
#
#
# Chavali (Black-Eyed Beans) Usal
# 				(Indian Food)
#
#
# Serving Size: 	1/2 cup cooked,
# 					Calories:  174,
# 					Fat:  5.8g,
# 					Carbs:  25.2g,
# 					Protein:  7.5g
#
#
# ['Chavali (Black-Eyed Beans) Usal ', '(Indian Food)', 'Serving Size: 1/2 cup cooked,', 'Calories:  174,', 'Fat:  5.8g,', 'Carbs:  25.2g,', 'Protein:  7.5g']
# ['Chavali (Black-Eyed Beans) Usal (Indian Food)', ' 1/2 cup cooked', '174', '5.8g', '25.2g', '7.5g']
# Chavali (Black-Eyed Beans) Usal (Indian Food) ,  1/2 cup cooked , 174 , 5.8g , 25.2g , 7.5g ,
#
#
#
# Chicken Beryani Rice
# 				(Indian Food)
#
#
# Serving Size: 	1 cup,
# 					Calories:  510.8,
# 					Fat:  16.1g,
# 					Carbs:  40.6g,
# 					Protein:  46.6g
#
#
# ['Chicken Beryani Rice ', '(Indian Food)', 'Serving Size: 1 cup,', 'Calories:  510.8,', 'Fat:  16.1g,', 'Carbs:  40.6g,', 'Protein:  46.6g']
# ['Chicken Beryani Rice (Indian Food)', ' 1 cup', '510.8', '16.1g', '40.6g', '46.6g']
# Chicken Beryani Rice (Indian Food) ,  1 cup , 510.8 , 16.1g , 40.6g , 46.6g ,
#
#
#
# Standard One Plate Buffet
# 				(Indian Food)
#
#
# Serving Size: 	1 dinner plate,
# 					Calories:  1500,
# 					Fat:  30g,
# 					Carbs:  60g,
# 					Protein:  10g
#
#
# ['Standard One Plate Buffet ', '(Indian Food)', 'Serving Size: 1 dinner plate,', 'Calories:  1500,', 'Fat:  30g,', 'Carbs:  60g,', 'Protein:  10g']
# ['Standard One Plate Buffet (Indian Food)', ' 1 dinner plate', '1500', '30g', '60g', '10g']
# Standard One Plate Buffet (Indian Food) ,  1 dinner plate , 1500 , 30g , 60g , 10g ,
#
#
#
# Onion Pakoda
# 				(Indian Food)
#
#
# Serving Size: 	1 cup cooked,
# 					Calories:  119,
# 					Fat:  1.8g,
# 					Carbs:  21.1g,
# 					Protein:  6.1g
#
#
# ['Onion Pakoda ', '(Indian Food)', 'Serving Size: 1 cup cooked,', 'Calories:  119,', 'Fat:  1.8g,', 'Carbs:  21.1g,', 'Protein:  6.1g']
# ['Onion Pakoda (Indian Food)', ' 1 cup cooked', '119', '1.8g', '21.1g', '6.1g']
# Onion Pakoda (Indian Food) ,  1 cup cooked , 119 , 1.8g , 21.1g , 6.1g ,
#
#
#
# Mutton / Lamb Biryani
# 				(Indian Food)
#
#
# Serving Size: 	1 plate cooked,
# 					Calories:  250,
# 					Fat:  11g,
# 					Carbs:  5g,
# 					Protein:  24g
#
#
# ['Mutton / Lamb Biryani ', '(Indian Food)', 'Serving Size: 1 plate cooked,', 'Calories:  250,', 'Fat:  11g,', 'Carbs:  5g,', 'Protein:  24g']
# ['Mutton / Lamb Biryani (Indian Food)', ' 1 plate cooked', '250', '11g', '5g', '24g']
# Mutton / Lamb Biryani (Indian Food) ,  1 plate cooked , 250 , 11g , 5g , 24g ,
#
#
#
# Mughlai Paratha
# 				(Indian Food)
#
#
# Serving Size: 	1 stuffed bread,
# 					Calories:  175,
# 					Fat:  11.5g,
# 					Carbs:  6.5g,
# 					Protein:  11.2g
#
#
# ['Mughlai Paratha ', '(Indian Food)', 'Serving Size: 1 stuffed bread,', 'Calories:  175,', 'Fat:  11.5g,', 'Carbs:  6.5g,', 'Protein:  11.2g']
# ['Mughlai Paratha (Indian Food)', ' 1 stuffed bread', '175', '11.5g', '6.5g', '11.2g']
# Mughlai Paratha (Indian Food) ,  1 stuffed bread , 175 , 11.5g , 6.5g , 11.2g ,
#
#
#
# Buffet Plate - Extra Chicken
# 				(Indian Food)
#
#
# Serving Size: 	1 plate,
# 					Calories:  400,
# 					Fat:  10g,
# 					Carbs:  20g,
# 					Protein:  20g
#
#
# ['Buffet Plate - Extra Chicken ', '(Indian Food)', 'Serving Size: 1 plate,', 'Calories:  400,', 'Fat:  10g,', 'Carbs:  20g,', 'Protein:  20g']
# ['Buffet Plate - Extra Chicken (Indian Food)', ' 1 plate', '400', '10g', '20g', '20g']
# Buffet Plate - Extra Chicken (Indian Food) ,  1 plate , 400 , 10g , 20g , 20g ,
#
#
#
# Sarevda-papdi
# 				(Indian Food)
#
#
# Serving Size: 	30 g,
# 					Calories:  90,
# 					Fat:  0g,
# 					Carbs:  20g,
# 					Protein:  1.5g
#
#
# ['Sarevda-papdi ', '(Indian Food)', 'Serving Size: 30 g,', 'Calories:  90,', 'Fat:  0g,', 'Carbs:  20g,', 'Protein:  1.5g']
# ['Sarevda-papdi (Indian Food)', ' 30 g', '90', '0g', '20g', '1.5g']
# Sarevda-papdi (Indian Food) ,  30 g , 90 , 0g , 20g , 1.5g ,
#
#
#
# Samosa - Meat and Veg
# 				(Indian Food)
#
#
# Serving Size: 	1 Samosa (35 Grams),
# 					Calories:  88,
# 					Fat:  2g,
# 					Carbs:  12.5g,
# 					Protein:  5g
#
#
# ['Samosa - Meat and Veg ', '(Indian Food)', 'Serving Size: 1 Samosa (35 Grams),', 'Calories:  88,', 'Fat:  2g,', 'Carbs:  12.5g,', 'Protein:  5g']
# ['Samosa - Meat and Veg (Indian Food)', ' 1 Samosa (35 Grams)', '88', '2g', '12.5g', '5g']
# Samosa - Meat and Veg (Indian Food) ,  1 Samosa (35 Grams) , 88 , 2g , 12.5g , 5g ,
#
#
#
# Naan bread
# 				(Indian food)
#
#
# Serving Size: 	100 g,
# 					Calories:  465,
# 					Fat:  25g,
# 					Carbs:  54g,
# 					Protein:  5g
#
#
# ['Naan bread ', '(Indian food)', 'Serving Size: 100 g,', 'Calories:  465,', 'Fat:  25g,', 'Carbs:  54g,', 'Protein:  5g']
# ['Naan bread (Indian food)', ' 100 g', '465', '25g', '54g', '5g']
# Naan bread (Indian food) ,  100 g , 465 , 25g , 54g , 5g ,
#
#
#
# Hing Spice
# 				(Indian Food)
#
#
# Serving Size: 	1/4 tsp,
# 					Calories:  4,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Hing Spice ', '(Indian Food)', 'Serving Size: 1/4 tsp,', 'Calories:  4,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Hing Spice (Indian Food)', ' 1/4 tsp', '4', '0g', '0g', '0g']
# Hing Spice (Indian Food) ,  1/4 tsp , 4 , 0g , 0g , 0g ,
#
#
#
# Khichdi
# 				(Indian Food)
#
#
# Serving Size: 	2 Plate,
# 					Calories:  103,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Khichdi ', '(Indian Food)', 'Serving Size: 2 Plate,', 'Calories:  103,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Khichdi (Indian Food)', ' 2 Plate', '103', '0g', '0g', '0g']
# Khichdi (Indian Food) ,  2 Plate , 103 , 0g , 0g , 0g ,
#
#
#
# Indian Food
# 				(Indian food)
#
#
# Serving Size: 	1 cup,
# 					Calories:  500,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Indian Food ', '(Indian food)', 'Serving Size: 1 cup,', 'Calories:  500,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Indian Food (Indian food)', ' 1 cup', '500', '0g', '0g', '0g']
# Indian Food (Indian food) ,  1 cup , 500 , 0g , 0g , 0g ,
#
#
#
# Lamb Madras Curry
# 				(Indian Food)
#
#
# Serving Size: 	1 cup,
# 					Calories:  270,
# 					Fat:  14g,
# 					Carbs:  13g,
# 					Protein:  23g
#
#
# ['Lamb Madras Curry ', '(Indian Food)', 'Serving Size: 1 cup,', 'Calories:  270,', 'Fat:  14g,', 'Carbs:  13g,', 'Protein:  23g']
# ['Lamb Madras Curry (Indian Food)', ' 1 cup', '270', '14g', '13g', '23g']
# Lamb Madras Curry (Indian Food) ,  1 cup , 270 , 14g , 13g , 23g ,
#
#
#
# Channa Dal Masala
# 				(Indian Food)
#
#
# Serving Size: 	1 cup,
# 					Calories:  290,
# 					Fat:  3g,
# 					Carbs:  55g,
# 					Protein:  11g
#
#
# ['Channa Dal Masala ', '(Indian Food)', 'Serving Size: 1 cup,', 'Calories:  290,', 'Fat:  3g,', 'Carbs:  55g,', 'Protein:  11g']
# ['Channa Dal Masala (Indian Food)', ' 1 cup', '290', '3g', '55g', '11g']
# Channa Dal Masala (Indian Food) ,  1 cup , 290 , 3g , 55g , 11g ,
#
#
#
# Chicken Makhani
# 				(Indian Food)
#
#
# Serving Size: 	1 cup,
# 					Calories:  409,
# 					Fat:  6g,
# 					Carbs:  63g,
# 					Protein:  14g
#
#
# ['Chicken Makhani ', '(Indian Food)', 'Serving Size: 1 cup,', 'Calories:  409,', 'Fat:  6g,', 'Carbs:  63g,', 'Protein:  14g']
# ['Chicken Makhani (Indian Food)', ' 1 cup', '409', '6g', '63g', '14g']
# Chicken Makhani (Indian Food) ,  1 cup , 409 , 6g , 63g , 14g ,
#
#
#
# Buffet Plate - Extra Chicken
# 				(Indian Food)
#
#
# Serving Size: 	1 plate,
# 					Calories:  400,
# 					Fat:  10g,
# 					Carbs:  20g,
# 					Protein:  20g
#
#
# ['Buffet Plate - Extra Chicken ', '(Indian Food)', 'Serving Size: 1 plate,', 'Calories:  400,', 'Fat:  10g,', 'Carbs:  20g,', 'Protein:  20g']
# ['Buffet Plate - Extra Chicken (Indian Food)', ' 1 plate', '400', '10g', '20g', '20g']
# Buffet Plate - Extra Chicken (Indian Food) ,  1 plate , 400 , 10g , 20g , 20g ,
#
#
#
# Aloo Gobi
# 				(Indian Food)
#
#
# Serving Size: 	1 Cup,
# 					Calories:  247,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Aloo Gobi ', '(Indian Food)', 'Serving Size: 1 Cup,', 'Calories:  247,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Aloo Gobi (Indian Food)', ' 1 Cup', '247', '0g', '0g', '0g']
# Aloo Gobi (Indian Food) ,  1 Cup , 247 , 0g , 0g , 0g ,
#
#
#
# Buffet
# 				(Indian food)
#
#
# Serving Size: 	1 plate,
# 					Calories:  1000,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Buffet ', '(Indian food)', 'Serving Size: 1 plate,', 'Calories:  1000,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Buffet (Indian food)', ' 1 plate', '1000', '0g', '0g', '0g']
# Buffet (Indian food) ,  1 plate , 1000 , 0g , 0g , 0g ,
#
#
#
# Standard One Plate Buffet
# 				(Indian Food)
#
#
# Serving Size: 	1 dinner plate,
# 					Calories:  1500,
# 					Fat:  30g,
# 					Carbs:  60g,
# 					Protein:  10g
#
#
# ['Standard One Plate Buffet ', '(Indian Food)', 'Serving Size: 1 dinner plate,', 'Calories:  1500,', 'Fat:  30g,', 'Carbs:  60g,', 'Protein:  10g']
# ['Standard One Plate Buffet (Indian Food)', ' 1 dinner plate', '1500', '30g', '60g', '10g']
# Standard One Plate Buffet (Indian Food) ,  1 dinner plate , 1500 , 30g , 60g , 10g ,
#
#
#
# Mutton / Lamb Biryani
# 				(Indian Food)
#
#
# Serving Size: 	1 plate cooked,
# 					Calories:  250,
# 					Fat:  11g,
# 					Carbs:  5g,
# 					Protein:  24g
#
#
# ['Mutton / Lamb Biryani ', '(Indian Food)', 'Serving Size: 1 plate cooked,', 'Calories:  250,', 'Fat:  11g,', 'Carbs:  5g,', 'Protein:  24g']
# ['Mutton / Lamb Biryani (Indian Food)', ' 1 plate cooked', '250', '11g', '5g', '24g']
# Mutton / Lamb Biryani (Indian Food) ,  1 plate cooked , 250 , 11g , 5g , 24g ,
#
#
#
# Chole (Curried Chickpeas)
# 				(Indian Food)
#
#
# Serving Size: 	1 Cup,
# 					Calories:  202,
# 					Fat:  7.6g,
# 					Carbs:  25.4g,
# 					Protein:  7.7g
#
#
# ['Chole (Curried Chickpeas) ', '(Indian Food)', 'Serving Size: 1 Cup,', 'Calories:  202,', 'Fat:  7.6g,', 'Carbs:  25.4g,', 'Protein:  7.7g']
# ['Chole (Curried Chickpeas) (Indian Food)', ' 1 Cup', '202', '7.6g', '25.4g', '7.7g']
# Chole (Curried Chickpeas) (Indian Food) ,  1 Cup , 202 , 7.6g , 25.4g , 7.7g ,
#
#
#
# Samosa - Meat and Veg
# 				(Indian Food)
#
#
# Serving Size: 	1 Samosa (35 Grams),
# 					Calories:  88,
# 					Fat:  2g,
# 					Carbs:  12.5g,
# 					Protein:  5g
#
#
# ['Samosa - Meat and Veg ', '(Indian Food)', 'Serving Size: 1 Samosa (35 Grams),', 'Calories:  88,', 'Fat:  2g,', 'Carbs:  12.5g,', 'Protein:  5g']
# ['Samosa - Meat and Veg (Indian Food)', ' 1 Samosa (35 Grams)', '88', '2g', '12.5g', '5g']
# Samosa - Meat and Veg (Indian Food) ,  1 Samosa (35 Grams) , 88 , 2g , 12.5g , 5g ,
#
#
#
# Lamb Madras Curry
# 				(Indian Food)
#
#
# Serving Size: 	1 cup,
# 					Calories:  270,
# 					Fat:  14g,
# 					Carbs:  13g,
# 					Protein:  23g
#
#
# ['Lamb Madras Curry ', '(Indian Food)', 'Serving Size: 1 cup,', 'Calories:  270,', 'Fat:  14g,', 'Carbs:  13g,', 'Protein:  23g']
# ['Lamb Madras Curry (Indian Food)', ' 1 cup', '270', '14g', '13g', '23g']
# Lamb Madras Curry (Indian Food) ,  1 cup , 270 , 14g , 13g , 23g ,
#
#
#
# Channa Dal Masala
# 				(Indian Food)
#
#
# Serving Size: 	1 cup,
# 					Calories:  290,
# 					Fat:  3g,
# 					Carbs:  55g,
# 					Protein:  11g
#
#
# ['Channa Dal Masala ', '(Indian Food)', 'Serving Size: 1 cup,', 'Calories:  290,', 'Fat:  3g,', 'Carbs:  55g,', 'Protein:  11g']
# ['Channa Dal Masala (Indian Food)', ' 1 cup', '290', '3g', '55g', '11g']
# Channa Dal Masala (Indian Food) ,  1 cup , 290 , 3g , 55g , 11g ,
#
#
#
# Chicken Makhani
# 				(Indian Food)
#
#
# Serving Size: 	1 cup,
# 					Calories:  409,
# 					Fat:  6g,
# 					Carbs:  63g,
# 					Protein:  14g
#
#
# ['Chicken Makhani ', '(Indian Food)', 'Serving Size: 1 cup,', 'Calories:  409,', 'Fat:  6g,', 'Carbs:  63g,', 'Protein:  14g']
# ['Chicken Makhani (Indian Food)', ' 1 cup', '409', '6g', '63g', '14g']
# Chicken Makhani (Indian Food) ,  1 cup , 409 , 6g , 63g , 14g ,
#
#
#
# Aloo Gobi
# 				(Indian Food)
#
#
# Serving Size: 	1 Cup,
# 					Calories:  247,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Aloo Gobi ', '(Indian Food)', 'Serving Size: 1 Cup,', 'Calories:  247,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Aloo Gobi (Indian Food)', ' 1 Cup', '247', '0g', '0g', '0g']
# Aloo Gobi (Indian Food) ,  1 Cup , 247 , 0g , 0g , 0g ,
#
#
#
# Buffet Plate - Extra Chicken
# 				(Indian Food)
#
#
# Serving Size: 	1 plate,
# 					Calories:  400,
# 					Fat:  10g,
# 					Carbs:  20g,
# 					Protein:  20g
#
#
# ['Buffet Plate - Extra Chicken ', '(Indian Food)', 'Serving Size: 1 plate,', 'Calories:  400,', 'Fat:  10g,', 'Carbs:  20g,', 'Protein:  20g']
# ['Buffet Plate - Extra Chicken (Indian Food)', ' 1 plate', '400', '10g', '20g', '20g']
# Buffet Plate - Extra Chicken (Indian Food) ,  1 plate , 400 , 10g , 20g , 20g ,
#
#
#
# Mutton / Lamb Biryani
# 				(Indian Food)
#
#
# Serving Size: 	1 plate cooked,
# 					Calories:  250,
# 					Fat:  11g,
# 					Carbs:  5g,
# 					Protein:  24g
#
#
# ['Mutton / Lamb Biryani ', '(Indian Food)', 'Serving Size: 1 plate cooked,', 'Calories:  250,', 'Fat:  11g,', 'Carbs:  5g,', 'Protein:  24g']
# ['Mutton / Lamb Biryani (Indian Food)', ' 1 plate cooked', '250', '11g', '5g', '24g']
# Mutton / Lamb Biryani (Indian Food) ,  1 plate cooked , 250 , 11g , 5g , 24g ,
#
#
#
# Samosa - Meat and Veg
# 				(Indian Food)
#
#
# Serving Size: 	1 Samosa (35 Grams),
# 					Calories:  88,
# 					Fat:  2g,
# 					Carbs:  12.5g,
# 					Protein:  5g
#
#
# ['Samosa - Meat and Veg ', '(Indian Food)', 'Serving Size: 1 Samosa (35 Grams),', 'Calories:  88,', 'Fat:  2g,', 'Carbs:  12.5g,', 'Protein:  5g']
# ['Samosa - Meat and Veg (Indian Food)', ' 1 Samosa (35 Grams)', '88', '2g', '12.5g', '5g']
# Samosa - Meat and Veg (Indian Food) ,  1 Samosa (35 Grams) , 88 , 2g , 12.5g , 5g ,
#
#
#
# Chole (Curried Chickpeas)
# 				(Indian Food)
#
#
# Serving Size: 	1 Cup,
# 					Calories:  202,
# 					Fat:  7.6g,
# 					Carbs:  25.4g,
# 					Protein:  7.7g
#
#
# ['Chole (Curried Chickpeas) ', '(Indian Food)', 'Serving Size: 1 Cup,', 'Calories:  202,', 'Fat:  7.6g,', 'Carbs:  25.4g,', 'Protein:  7.7g']
# ['Chole (Curried Chickpeas) (Indian Food)', ' 1 Cup', '202', '7.6g', '25.4g', '7.7g']
# Chole (Curried Chickpeas) (Indian Food) ,  1 Cup , 202 , 7.6g , 25.4g , 7.7g ,
#
#
#
# Standard One Plate Buffet
# 				(Indian Food)
#
#
# Serving Size: 	1 dinner plate,
# 					Calories:  1500,
# 					Fat:  30g,
# 					Carbs:  60g,
# 					Protein:  10g
#
#
# ['Standard One Plate Buffet ', '(Indian Food)', 'Serving Size: 1 dinner plate,', 'Calories:  1500,', 'Fat:  30g,', 'Carbs:  60g,', 'Protein:  10g']
# ['Standard One Plate Buffet (Indian Food)', ' 1 dinner plate', '1500', '30g', '60g', '10g']
# Standard One Plate Buffet (Indian Food) ,  1 dinner plate , 1500 , 30g , 60g , 10g ,
#
#
#
# Buffet
# 				(Indian food)
#
#
# Serving Size: 	1 each,
# 					Calories:  1000,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Buffet ', '(Indian food)', 'Serving Size: 1 each,', 'Calories:  1000,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Buffet (Indian food)', ' 1 each', '1000', '0g', '0g', '0g']
# Buffet (Indian food) ,  1 each , 1000 , 0g , 0g , 0g ,
#
#
#
# Buffet
# 				(Indian food)
#
#
# Serving Size: 	1 each,
# 					Calories:  1000,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Buffet ', '(Indian food)', 'Serving Size: 1 each,', 'Calories:  1000,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Buffet (Indian food)', ' 1 each', '1000', '0g', '0g', '0g']
# Buffet (Indian food) ,  1 each , 1000 , 0g , 0g , 0g ,
#
#
#
# 2 Chapati and Green Sabji
# 				(Indian Food)
#
#
# Serving Size: 	2 cooked,
# 					Calories:  70,
# 					Fat:  5g,
# 					Carbs:  5.8g,
# 					Protein:  0g
#
#
# ['2 Chapati and Green Sabji ', '(Indian Food)', 'Serving Size: 2 cooked,', 'Calories:  70,', 'Fat:  5g,', 'Carbs:  5.8g,', 'Protein:  0g']
# ['2 Chapati and Green Sabji (Indian Food)', ' 2 cooked', '70', '5g', '5.8g', '0g']
# 2 Chapati and Green Sabji (Indian Food) ,  2 cooked , 70 , 5g , 5.8g , 0g ,
#
#
#
# Puri
# 				(Indian Food)
#
#
# Serving Size: 	1 piece,
# 					Calories:  112,
# 					Fat:  5g,
# 					Carbs:  16g,
# 					Protein:  3g
#
#
# ['Puri ', '(Indian Food)', 'Serving Size: 1 piece,', 'Calories:  112,', 'Fat:  5g,', 'Carbs:  16g,', 'Protein:  3g']
# ['Puri (Indian Food)', ' 1 piece', '112', '5g', '16g', '3g']
# Puri (Indian Food) ,  1 piece , 112 , 5g , 16g , 3g ,
#
#
#
# Chicken Makhani
# 				(Indian Food)
#
#
# Serving Size: 	6 oz,
# 					Calories:  350,
# 					Fat:  25g,
# 					Carbs:  6g,
# 					Protein:  25g
#
#
# ['Chicken Makhani ', '(Indian Food)', 'Serving Size: 6 oz,', 'Calories:  350,', 'Fat:  25g,', 'Carbs:  6g,', 'Protein:  25g']
# ['Chicken Makhani (Indian Food)', ' 6 oz', '350', '25g', '6g', '25g']
# Chicken Makhani (Indian Food) ,  6 oz , 350 , 25g , 6g , 25g ,
#
#
#
# Chicken Saag
# 				(Indian Food)
#
#
# Serving Size: 	1 cup,
# 					Calories:  290,
# 					Fat:  10g,
# 					Carbs:  35g,
# 					Protein:  19g
#
#
# ['Chicken Saag ', '(Indian Food)', 'Serving Size: 1 cup,', 'Calories:  290,', 'Fat:  10g,', 'Carbs:  35g,', 'Protein:  19g']
# ['Chicken Saag (Indian Food)', ' 1 cup', '290', '10g', '35g', '19g']
# Chicken Saag (Indian Food) ,  1 cup , 290 , 10g , 35g , 19g ,
#
#
#
# Cooked Chickpeas
# 				(Indian Food)
#
#
# Serving Size: 	350 g,
# 					Calories:  462,
# 					Fat:  9g,
# 					Carbs:  82g,
# 					Protein:  13g
#
#
# ['Cooked Chickpeas ', '(Indian Food)', 'Serving Size: 350 g,', 'Calories:  462,', 'Fat:  9g,', 'Carbs:  82g,', 'Protein:  13g']
# ['Cooked Chickpeas (Indian Food)', ' 350 g', '462', '9g', '82g', '13g']
# Cooked Chickpeas (Indian Food) ,  350 g , 462 , 9g , 82g , 13g ,
#
#
#
# Aloo Paratha
# 				(Indian Food)
#
#
# Serving Size: 	1 (216G),
# 					Calories:  390,
# 					Fat:  7.9g,
# 					Carbs:  65g,
# 					Protein:  9.6g
#
#
# ['Aloo Paratha ', '(Indian Food)', 'Serving Size: 1 (216G),', 'Calories:  390,', 'Fat:  7.9g,', 'Carbs:  65g,', 'Protein:  9.6g']
# ['Aloo Paratha (Indian Food)', ' 1 (216G)', '390', '7.9g', '65g', '9.6g']
# Aloo Paratha (Indian Food) ,  1 (216G) , 390 , 7.9g , 65g , 9.6g ,
#
#
#
# Moong Dal (Yellow Split Lentils)
# 				(Indian Food)
#
#
# Serving Size: 	100 gm,
# 					Calories:  358,
# 					Fat:  1.2g,
# 					Carbs:  59.9g,
# 					Protein:  24.5g
#
#
# ['Moong Dal (Yellow Split Lentils) ', '(Indian Food)', 'Serving Size: 100 gm,', 'Calories:  358,', 'Fat:  1.2g,', 'Carbs:  59.9g,', 'Protein:  24.5g']
# ['Moong Dal (Yellow Split Lentils) (Indian Food)', ' 100 gm', '358', '1.2g', '59.9g', '24.5g']
# Moong Dal (Yellow Split Lentils) (Indian Food) ,  100 gm , 358 , 1.2g , 59.9g , 24.5g ,
#
#
#
# Lamb Madras Curry
# 				(Indian Food)
#
#
# Serving Size: 	1 cup,
# 					Calories:  270,
# 					Fat:  14g,
# 					Carbs:  13g,
# 					Protein:  23g
#
#
# ['Lamb Madras Curry ', '(Indian Food)', 'Serving Size: 1 cup,', 'Calories:  270,', 'Fat:  14g,', 'Carbs:  13g,', 'Protein:  23g']
# ['Lamb Madras Curry (Indian Food)', ' 1 cup', '270', '14g', '13g', '23g']
# Lamb Madras Curry (Indian Food) ,  1 cup , 270 , 14g , 13g , 23g ,
#
#
#
# Aloo Mutter Paneer - Diced Potato, Cottage Cheese and Pea Curry
# 				(Indian Food)
#
#
# Serving Size: 	100 G,
# 					Calories:  106,
# 					Fat:  4.8g,
# 					Carbs:  13.3g,
# 					Protein:  2.5g
#
#
# ['Aloo Mutter Paneer - Diced Potato, Cottage Cheese and Pea Curry ', '(Indian Food)', 'Serving Size: 100 G,', 'Calories:  106,', 'Fat:  4.8g,', 'Carbs:  13.3g,', 'Protein:  2.5g']
# ['Aloo Mutter Paneer - Diced Potato Cottage Cheese and Pea Curry (Indian Food)', ' 100 G', '106', '4.8g', '13.3g', '2.5g']
# Aloo Mutter Paneer - Diced Potato Cottage Cheese and Pea Curry (Indian Food) ,  100 G , 106 , 4.8g , 13.3g , 2.5g ,
#
#
#
# Chicken Briani
# 				(Indian Food)
#
#
# Serving Size: 	365 gm,
# 					Calories:  520,
# 					Fat:  12g,
# 					Carbs:  81g,
# 					Protein:  23g
#
#
# ['Chicken Briani ', '(Indian Food)', 'Serving Size: 365 gm,', 'Calories:  520,', 'Fat:  12g,', 'Carbs:  81g,', 'Protein:  23g']
# ['Chicken Briani (Indian Food)', ' 365 gm', '520', '12g', '81g', '23g']
# Chicken Briani (Indian Food) ,  365 gm , 520 , 12g , 81g , 23g ,
#
#
#
# Aloo Baigan
# 				(Indian Food)
#
#
# Serving Size: 	1 (271g),
# 					Calories:  191,
# 					Fat:  9.9g,
# 					Carbs:  24.6g,
# 					Protein:  3.8g
#
#
# ['Aloo Baigan ', '(Indian Food)', 'Serving Size: 1 (271g),', 'Calories:  191,', 'Fat:  9.9g,', 'Carbs:  24.6g,', 'Protein:  3.8g']
# ['Aloo Baigan (Indian Food)', ' 1 (271g)', '191', '9.9g', '24.6g', '3.8g']
# Aloo Baigan (Indian Food) ,  1 (271g) , 191 , 9.9g , 24.6g , 3.8g ,
#
#
#
# Channa Dal Masala
# 				(Indian Food)
#
#
# Serving Size: 	1 cup,
# 					Calories:  290,
# 					Fat:  3g,
# 					Carbs:  55g,
# 					Protein:  11g
#
#
# ['Channa Dal Masala ', '(Indian Food)', 'Serving Size: 1 cup,', 'Calories:  290,', 'Fat:  3g,', 'Carbs:  55g,', 'Protein:  11g']
# ['Channa Dal Masala (Indian Food)', ' 1 cup', '290', '3g', '55g', '11g']
# Channa Dal Masala (Indian Food) ,  1 cup , 290 , 3g , 55g , 11g ,
#
#
#
# Aloo Gobi
# 				(Indian Food)
#
#
# Serving Size: 	1 Cup,
# 					Calories:  247,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Aloo Gobi ', '(Indian Food)', 'Serving Size: 1 Cup,', 'Calories:  247,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Aloo Gobi (Indian Food)', ' 1 Cup', '247', '0g', '0g', '0g']
# Aloo Gobi (Indian Food) ,  1 Cup , 247 , 0g , 0g , 0g ,
#
#
#
# Vegetable Biryani
# 				(Indian Food)
#
#
# Serving Size: 	1 Cup,
# 					Calories:  290,
# 					Fat:  0g,
# 					Carbs:  0g,
# 					Protein:  0g
#
#
# ['Vegetable Biryani ', '(Indian Food)', 'Serving Size: 1 Cup,', 'Calories:  290,', 'Fat:  0g,', 'Carbs:  0g,', 'Protein:  0g']
# ['Vegetable Biryani (Indian Food)', ' 1 Cup', '290', '0g', '0g', '0g']
# Vegetable Biryani (Indian Food) ,  1 Cup , 290 , 0g , 0g , 0g ,
#
#
#
# Mooli Paratha
# 				(Indian Food)
#
#
# Serving Size: 	1 (83G),
# 					Calories:  180,
# 					Fat:  6g,
# 					Carbs:  30g,
# 					Protein:  5g
#
#
# ['Mooli Paratha ', '(Indian Food)', 'Serving Size: 1 (83G),', 'Calories:  180,', 'Fat:  6g,', 'Carbs:  30g,', 'Protein:  5g']
# ['Mooli Paratha (Indian Food)', ' 1 (83G)', '180', '6g', '30g', '5g']
# Mooli Paratha (Indian Food) ,  1 (83G) , 180 , 6g , 30g , 5g ,
#
#
#
# Chole (Curried Chickpeas)
# 				(Indian Food)
#
#
# Serving Size: 	1 Cup,
# 					Calories:  202,
# 					Fat:  7.6g,
# 					Carbs:  25.4g,
# 					Protein:  7.7g
#
#
# ['Chole (Curried Chickpeas) ', '(Indian Food)', 'Serving Size: 1 Cup,', 'Calories:  202,', 'Fat:  7.6g,', 'Carbs:  25.4g,', 'Protein:  7.7g']
# ['Chole (Curried Chickpeas) (Indian Food)', ' 1 Cup', '202', '7.6g', '25.4g', '7.7g']
# Chole (Curried Chickpeas) (Indian Food) ,  1 Cup , 202 , 7.6g , 25.4g , 7.7g ,

# %%
! pip install urlparse2
# Out:
# Collecting urlparse2
#   Downloading https://files.pythonhosted.org/packages/ad/39/93ce76ba9f62c5400b8ac93990aa7c97cbcc5157d03b81ee88ab01e9997e/urlparse2-1.1.1.tar.gz
# Collecting recordtype (from urlparse2)
#   Downloading https://files.pythonhosted.org/packages/cc/1c/7ff90f4379110d6ef92a7f44ce487f235dbb3243f17c5294a73e0156b6f4/recordtype-1.1.tar.gz
# Building wheels for collected packages: urlparse2, recordtype
# done
#   Stored in directory: /content/.cache/pip/wheels/bb/03/c5/38603182555420e387d701c60e9358af52d6a11c8d656b8c0d
# done
#   Stored in directory: /content/.cache/pip/wheels/26/53/29/4932edc277a1d63d215b2f441bd66ef35e358bd02e317f8dc8
# Successfully built urlparse2 recordtype
# Installing collected packages: recordtype, urlparse2
# Successfully installed recordtype-1.1 urlparse2-1.1.1

# %%
! pip install html2text
# Out:
# Collecting html2text
#   Downloading https://files.pythonhosted.org/packages/16/20/de2b458ef434713053dd83209a03a5431ebe0527c8e14d9ae7838ff67d8a/html2text-2018.1.9-py3-none-any.whl
# Installing collected packages: html2text
# Successfully installed html2text-2018.1.9

# %%
import pandas as pd
data=pd.read_csv('./Indian Food Nutrition.csv')
print(len(data))
# Out:
# 75
